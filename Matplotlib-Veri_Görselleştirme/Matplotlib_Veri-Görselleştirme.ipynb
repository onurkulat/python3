# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
x=np.arange(1,6)

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y=np.arange(2,11,2)

# %%
y
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
plt.plot(x,y,"blue")#y=2x grafiği

# %%
plt.subplot(2,2,1)
plt.plot(x,y,"blue")
plt.subplot(2,2,2)
plt.plot(y,x,"red")
plt.subplot(2,2,3)
plt.plot(x**2,y,"green")
plt.subplot(2,2,4)
plt.plot(x,y**2,"black")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.arange(1,6)
y=np.arange(2,11,2)

fig=plt.figure()

axes1=fig.add_axes([0.1,0.1,0.8,0.8])#sol,alttan,x,y
axes2=fig.add_axes([0.2,0.5,0.2,0.3])

axes1.plot(y,x)
axes1.set_xlabel("Outher X")
axes1.set_ylabel("Outher Y")
axes1.set_title("Outher Graph")

axes2.plot(x,y)
axes1.set_xlabel("Inner X")
axes1.set_ylabel("Inner Y")
axes1.set_title("Inner Graph")

plt.show()

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
fig,axes=plt.subplots(nrows=2,ncols=2)
plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=2,ncols=1)
plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=2,ncols=1)

for ax in axes:
    ax.plot(x,y)

plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=2,ncols=1)

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=2,ncols=1)

axes[0].plot(x,y)
axes[0].set_title("First Axes")
axes[1].plot(x,x**3)
axes[1].set_title("Second Axes")
plt.tight_layout()

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="purple")

# %%
fig=plt.figure(figsize=(4,4))
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="purple")

# %%
fig=plt.figure(figsize=(8,6))
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,color="purple")

# %%
fig,axes=plt.subplots(nrows=2,ncols=1,figsize=(8,6))
axes[0].plot(x,y,color="red")
axes[0].set_title("First Axes")
axes[1].plot(x,x**0.5,color="black")
axes[1].set_title("Second Axes")
plt.tight_layout()

# %% [markdown]
# figürü kaydetmek için;

# %%
fig.savefig("Figure1.png")

# %%
fig.savefig("Figure1.pdf")

# %%
fig=plt.figure(figsize=(6,4))
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**0.5,color="red",label="X Karekök")
axes.plot(x,x**2,color="yellow",label="X Kare")
axes.plot(x,x**3,color="#5c7d84",label="X Küp")
axes.legend()

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,color="red",lineWidth=3)

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,color="red",lineWidth=3,linestyle="--")

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,color="red",lineWidth=3,linestyle=":")

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,color="red",lw=3,ls="-.")

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,color="red",lineWidth=3,marker="o")

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,color="red",lineWidth=3,marker="o",ms=10,markerfacecolor="black")

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,color="red",lineWidth=3,marker="o",ms=10,markerfacecolor="black",
         markeredgecolor="yellow",markeredgewidth=3)

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,color="red",lineWidth=3,marker="o",ms=10,markerfacecolor="black",
         markeredgecolor="yellow",markeredgewidth=3)

axes.set_xlim(0,20)
axes.set_ylim(0,50)
# Out:
# (0, 50)
